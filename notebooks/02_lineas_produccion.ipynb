# %% [markdown]
# # 02 · Líneas de código en ramas de producción
#
# Productivity Tracker · Innovación Automotriz SpA
#
# Mide líneas agregadas/eliminadas por dev en las ramas de producción (main/master) de los repos de `Auto-Innovation-Lab`, como complemento al análisis de commits.

# %%
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

load_dotenv()  # lee .env en la raíz del repo (no versionado)

GITHUB_TOKEN = os.environ.get("GITHUB_TOKEN")
GITHUB_ORG = os.environ.get("GITHUB_ORG", "Auto-Innovation-Lab")
GITHUB_USERNAME = os.environ.get("GITHUB_USERNAME", "edesiosantos")

# %% [markdown]
# ## Configuración

# %%
# TODO: definir repos y ramas de producción a analizar (main/master)

# %% [markdown]
# ## Extracción de stats de commits (additions/deletions)

# %%
# TODO: usar API de GitHub (stats/contributors o commits) para obtener líneas +/-

# %% [markdown]
# ## Agregación por dev y periodo

# %%
# TODO: construir dataframe con líneas por dev/semana/mes

# %% [markdown]
# ## Visualización de tendencias

# %%
# TODO: graficar líneas de código por dev antes/después de adopción de IA
