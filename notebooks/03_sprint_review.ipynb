# %% [markdown]
# # 03 · Análisis de estimaciones por sprint
#
# Productivity Tracker · Innovación Automotriz SpA
#
# Compara las estimaciones de sprints contra la base histórica (`data/base/base_estimacion_sprints.xlsx`) y el historial sin IA (`data/historial/Sprint_60.xlsx`), para medir la evolución de las estimaciones tras adoptar Claude Code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path("../data")
BASE_PATH = DATA_DIR / "base" / "base_estimacion_sprints.xlsx"
HISTORIAL_PATH = DATA_DIR / "historial" / "Sprint_60.xlsx"
SPRINTS_DIR = DATA_DIR / "sprints"

# %% [markdown]
# ## Carga de base histórica

# %%
# TODO: cargar base_estimacion_sprints.xlsx (Hist / Meta / Desafío por tipo de tarea)

# %% [markdown]
# ## Carga de historial sin IA (sprints 18-59)

# %%
# TODO: cargar Sprint_60.xlsx como referencia histórica

# %% [markdown]
# ## Carga del sprint nuevo a revisar

# %%
# TODO: cargar el sprint más reciente desde data/sprints/

# %% [markdown]
# ## Clasificación de tareas (DESAFÍO / META / OK / ALTA / INFLADA)

# %%
# TODO: detectar tipo de tarea por título y comparar contra Hist/Meta/Desafío

# %% [markdown]
# ## Resumen ejecutivo y tendencias entre sprints

# %%
# TODO: distribución de estados y evolución sprint a sprint
